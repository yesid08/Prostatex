# %%
import os
import pydicom
import math
from pydicom.data import get_testdata_files
import matplotlib.pyplot as plt

# %%
files = os.listdir()
filename = files[1]
counter = 1
ds = pydicom.dcmread(fp=filename)
print ("Datos del paciente")
print("ID: %s" % ds.PatientID)
print("Nombre: %s" % ds.PatientName)
print("Edad: %s " % ds.PatientAge)
print("Peso: %s [Kg]" % ds.PatientWeight)
print("Fecha de nacimiento: %s" % ds.PatientBirthDate)
print("Posición: %s" % ds.PatientPosition)

for file in files:
    if (file.find("dcm") >= 0):
        ds = pydicom.dcmread(file)
        image = ds.pixel_array
        plt.figure()
        plt.title("Image %s" %counter)
        plt.imshow(image)
        counter = counter + 1
# Out:
# Datos del paciente
# ID: ProstateX-0000
# Nombre: ProstateX-0000
# Edad: 063Y
# Peso: 77 [Kg]
# Fecha de nacimiento:
# Posición: FFS

# %%
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# (0008, 0012) Instance Creation Date              DA: '20110707'
# (0008, 0013) Instance Creation Time              TM: '115243.140000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.166550895917507970053841398592
# (0008, 0020) Study Date                          DA: '20110707'
# (0008, 0021) Series Date                         DA: '20110707'
# (0008, 0022) Acquisition Date                    DA: '20110707'
# (0008, 0023) Content Date                        DA: '20110707'
# (0008, 0030) Study Time                          TM: '114731.187000'
# (0008, 0031) Series Time                         TM: '115243.109000'
# (0008, 0032) Acquisition Time                    TM: '114955.197500'
# (0008, 0033) Content Time                        TM: '115243.140000'
# (0008, 0050) Accession Number                    SH: '2037145102504919'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 't2_tse_sag'
# (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
# (0008, 1110)  Referenced Study Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.124158868363483996200915242911
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.139368213297451029100299662451
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.275375112386820707860119069066
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0000'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0000'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '063Y'
# (0010, 1020) Patient's Size                      DS: "1.83"
# (0010, 1030) Patient's Weight                    DS: "77"
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['DIAG-ANON 0.3', 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064']
# (0012, 0064)  De-identification Method Code Sequence   8 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113104'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Structured Content Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'PROSTATEx'
# (0013, 1013) Private tag data                    LO: '73115101'
# (0018, 0015) Body Part Examined                  CS: 'PROSTATE'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: 'SAT1'
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: '*tse2d1_25'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "3"
# (0018, 0080) Repetition Time                     DS: "5590"
# (0018, 0081) Echo Time                           DS: "101"
# (0018, 0083) Number of Averages                  DS: "3"
# (0018, 0084) Imaging Frequency                   DS: "123.242441"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "3.6"
# (0018, 0089) Number of Phase Encoding Steps      IS: '500'
# (0018, 0091) Echo Train Length                   IS: '25'
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "100"
# (0018, 0095) Pixel Bandwidth                     DS: "200"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR D11'
# (0018, 1030) Protocol Name                       LO: 't2_tse_sag'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [0, 320, 320, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: "160"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "1.6654975543857"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 100b) [SliceMeasurementDuration]          OB: b'162377.5'
# (0019, 100f) [GradientMode]                      OB: b'Normal'
# (0019, 1011) [FlowCompensation]                  OB: b'No'
# (0019, 1012) [TablePositionOrigin]               OB: b'\x00\x00\x00\x00\x00\x00\x00\x00\xa5\xf8\xff\xff'
# (0019, 1013) [ImaAbsTablePosition]               OB: b'\x00\x00\x00\x00\x00\x00\x00\x00\xc7\xf8\xff\xff'
# (0019, 1014) [ImaRelTablePosition]               OB: b'0\\0\\-34 '
# (0019, 1015) [SlicePosition_PCS]                 OB: Array of 24 bytes
# (0019, 1017) [SliceResolution]                   OB: b'1 '
# (0019, 1018) [RealDwellTime]                     OB: b'7800'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.250911858840767891342974687368
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '3'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '8'
# (0020, 0032) Image Position (Patient)            DS: ['31.762851715088', '-66.736778259277', '56.274690240622']
# (0020, 0037) Image Orientation (Patient)         DS: ['0', '1', '0', '0', '0', '-1']
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.7311.5101.167989189699391273938467151375
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "31.762851715088"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 320
# (0028, 0011) Columns                             US: 320
# (0028, 0030) Pixel Spacing                       DS: ['0.5625', '0.5625']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 932
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: "618"
# (0028, 1051) Window Width                        DS: "1206"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1160) [Series Workflow Status]            OB: b'com '
# (0031, 0010) Private Creator                     LO: 'AGFA PACS Archive Mirroring 1.0'
# (0032, 000a) Study Status ID                     CS: 'READ'
# (0032, 000c) Study Priority ID                   CS: 'MED'
# (0032, 1030) Reason for Study                    LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0032, 1060) Requested Procedure Description     LO: 'MR prostaat kanker detectie WDS_mc'
# (0033, 0010) Private Creator                     LO: 'MITRA OBJECT UTF8 ATTRIBUTES 1.0'
# (0040, 0244) Performed Procedure Step Start Date DA: '20110707'
# (0040, 0245) Performed Procedure Step Start Time TM: '114731.250000'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MR prostaat kanker detectie WDS_mc'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             OB: b'IMAGE NUM 4 '
# (0051, 1009) [CSA Image Header Version ??]       OB: b'1.0 '
# (0051, 100b) [AcquisitionMatrixText]             OB: b'320*320 '
# (0051, 100f) [CoilString]                        OB: b'BO1-3;SP4-6 '
# (0051, 1013) [PositivePCSDirections]             OB: b'+LPH'
# (7fe0, 0010) Pixel Data                          OW: Array of 204800 bytes

# %%
os.listdir??

# %%
int(math.sqrt(5))
# Out:
# 2
